# %% [markdown]
# # INDIAN PREMIER LEAGUE (IPL) MATCH DATA ANALYSIS: 2008-2017

# %% [markdown]
# The dataset contains detailed information on IPL matches played from 2008 to 2017. It includes match-related attributes such as innings, batting and bowling teams, runs scored, dismissals, match outcomes, player statistics, venue details, and umpire information. With over 11415 matches recorded, this dataset offers a comprehensive view of IPL cricket during this period.

# %% [markdown]
# # DATASET SOURCE:

# %% [markdown]
# The dataset was sourced from https://github.com/MainakRepositor/Datasets/tree/master/IPL

# %% [markdown]
# The dataset comprises three CSV files: deliveries.csv, matches.csv, and most_runs_average_strikerate.csv.

# %% [markdown]
# # DATASET ATTRIBUTES:

# %% [markdown]
# # deliveries.csv

# %% [raw]
# match_id         : Unique identifier for each match.
# inning           : Inning number (1st or 2nd innings).
# batting_team     : Team batting in the current innings.
# bowling_team     : Team bowling in the current innings.
# over             : Over number in the match.
# ball             : Ball number within the over.
# batsman          : Player currently facing the ball.
# non_striker      : Player not facing the ball.
# bowler           : Bowler delivering the ball.
# is_super_over    : Indicates if the current over is a super over (1 for yes, 0 for no).
# wide_runs        : Number of wide runs conceded by the bowling team.
# bye_runs         : Number of bye runs conceded by the bowling team.
# legbye_runs      : Number of leg bye runs conceded by the bowling team.
# noball_runs      : Number of no-ball runs conceded by the bowling team.
# penalty_runs     : Number of penalty runs conceded by the bowling team.
# batsman_runs     : Runs scored off the bat by the batsman.
# extra_runs       : Extra runs conceded by the bowling team (excluding wides, byes, leg byes, no balls, and penalties).
# total_runs       : Total runs scored in the current delivery (including extras).
# player_dismissed : Batsman dismissed in the current delivery.
# dismissal_kind   : Type of dismissal (e.g., bowled, caught, run out).
# fielder          : Fielder involved in the dismissal.

# %% [markdown]
# # matches.csv

# %% [raw]
# id               : Unique identifier for each match.
# Season           : Season of the IPL.
# city             : City where the match was played.
# date             : Date of the match.
# team1            : First team playing the match.
# team2            : Second team playing the match.
# toss_winner      : Team winning the toss.
# toss_decision    : Decision taken by the toss-winning team (bat or bowl).
# result           : Result of the match (normal, tie, no result).
# dl_applied       : Indicates if the Duckworth-Lewis method was applied (1 for yes, 0 for no).
# winner           : Winning team of the match.
# win_by_runs      : Margin of victory (runs) if the winning team batted first.
# win_by_wickets   : Number of wickets remaining if the winning team chased the target.
# player_of_match  : Player of the match.
# venue            : Stadium where the match was played.
# umpire1          : First umpire officiating the match.
# umpire2          : Second umpire officiating the match.
# umpire3          : Third umpire officiating the match (if applicable).

# %% [markdown]
# # most_runs_average_strikerate.csv

# %% [raw]
# total_runs       : Total runs scored in the overall matches by the player.
# out              : Number of dismissals in the match.
# numberofballs    : Total number of balls bowled in the match.
# average          : Batting average of the batsman.
# strikerate       : Batting strike rate of the batsman.

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings("ignore")
# Out:
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # LOADING THE DATASET

# %%
df1=pd.read_csv(r'deliveries.csv')

# %%
df2=pd.read_csv(r'matches.csv')

# %%
df3=pd.read_csv(r'most_runs_average_strikerate.csv')

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# ## HANDLING THE MISSING VALUES

# %% [markdown]
# ## 1. deliveries.csv

# %%
df1
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df1.shape
# Out:
# (179078, 21)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
df1['batting_team'].value_counts()
# Out:
# batting_team
# Mumbai Indians                 22619
# Kings XI Punjab                20931
# Royal Challengers Bangalore    20908
# Kolkata Knight Riders          20858
# Chennai Super Kings            19762
# Delhi Daredevils               18786
# Rajasthan Royals               17292
# Sunrisers Hyderabad            12908
# Deccan Chargers                 9034
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Delhi Capitals                  1909
# Rising Pune Supergiant          1900
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: count, dtype: int64

# %%
#checking for null values
df1.isnull().any()
# Out:
# match_id            False
# inning              False
# batting_team        False
# bowling_team        False
# over                False
# ball                False
# batsman             False
# non_striker         False
# bowler              False
# is_super_over       False
# wide_runs           False
# bye_runs            False
# legbye_runs         False
# noball_runs         False
# penalty_runs        False
# batsman_runs        False
# extra_runs          False
# total_runs          False
# player_dismissed     True
# dismissal_kind       True
# fielder              True
# dtype: bool

# %%
#checking for how many missing values
df1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %% [markdown]
# dropping the columns "player_dismissed", "dismissal_kind", and "fielder" due to the high number of missing values. These columns have a large proportion of missing values compared to the total number of records in the dataset, which could potentially affect the quality and reliability of any analysis or modeling performed using these columns. Additionally, these columns may not be essential for the specific analysis or research question at hand, making their exclusion a reasonable decision to streamline the dataset and focus on relevant information.

# %%
#Dropping the Columns:

# %%
df1.drop(columns=['player_dismissed', 'dismissal_kind', 'fielder'], inplace=True)

# %%
df1.isnull().sum()
# Out:
# match_id         0
# inning           0
# batting_team     0
# bowling_team     0
# over             0
# ball             0
# batsman          0
# non_striker      0
# bowler           0
# is_super_over    0
# wide_runs        0
# bye_runs         0
# legbye_runs      0
# noball_runs      0
# penalty_runs     0
# batsman_runs     0
# extra_runs       0
# total_runs       0
# dtype: int64

# %% [markdown]
# # 2. matches.csv

# %%
df2
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df2.shape
# Out:
# (756, 18)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df2.isnull().any()
# Out:
# id                 False
# Season             False
# city                True
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result             False
# dl_applied         False
# winner              True
# win_by_runs        False
# win_by_wickets     False
# player_of_match     True
# venue              False
# umpire1             True
# umpire2             True
# umpire3             True
# dtype: bool

# %%
df2.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# We're dropping the "umpire3" column due to the high number of missing values (637 out of 756), which significantly limits its usefulness for analysis. The missing values in "umpire1" and "umpire2" will be filled with "unknown" as there are only 2 missing values, and the names of the umpires are not available.
#
# For "player_of_match" and "winner" columns, the missing values likely indicate that no player was awarded the "Player of the Match" or there was no winner due to no match. Therefore, we will fill the missing values in these columns with "No Game Day".
#
# Regarding the "city" column, after analyzing the venue information, we observed that most matches were played in Dubai where the city information was missing. Therefore, we will fill the missing values in the "city" column with "Dubai".

# %%
#Dropping the umpire3:

# %%
df2.drop(columns=['umpire3'], inplace=True)

# %%
# Filling the missing values in umpire1 and umpire2 with 'unknown':

# %%
df2['umpire1'].fillna('unknown', inplace=True)
df2['umpire2'].fillna('unknown', inplace=True)

# %%
# Filling the missing values in city with 'Dubai':

# %%
df2['city'].fillna('Dubai', inplace=True)

# %%
#Filling the missing values in winner with 'No Game Day'

# %%
df2['winner'].fillna('No Game Day', inplace=True)

# %%
#Filling the missing values in player_of_match with 'No Game Day'

# %%
df2['player_of_match'].fillna('No Game Day', inplace=True)

# %%
df2['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# No Game Day                      4
# Name: count, dtype: int64

# %%
df2.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# ## 3. most_runs_average_strikerate.csv

# %%
df3
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
df3.shape
# Out:
# (516, 6)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
df3.isnull().any()
# Out:
# batsman          False
# total_runs       False
# out              False
# numberofballs    False
# average           True
# strikerate       False
# dtype: bool

# %%
df3.isnull().sum()
# Out:
# batsman           0
# total_runs        0
# out               0
# numberofballs     0
# average          34
# strikerate        0
# dtype: int64

# %% [markdown]
# We're filling the missing values in the "average" column by calculating the batting average for each player. Since batting average is calculated by dividing the total runs scored by the number of times dismissed (outs), we're using this formula:total_runs/out to impute the missing values. This approach ensures that each player's average reflects their performance based on the runs scored and the number of times they were dismissed.

# %%
# Filling the missing values in average by dividing total_runs by out
average_values = df3['total_runs'] / df3['out']

# Replacing the infinite values with 'can't define' and NaNs with 0
average_values = average_values.replace([np.inf, -np.inf], "can't define").fillna(0)

# Updating the average column with the calculated values
df3['average'] = df3['average'].fillna(average_values)

# %%
df3.isnull().sum()
# Out:
# batsman          0
# total_runs       0
# out              0
# numberofballs    0
# average          0
# strikerate       0
# dtype: int64

# %% [markdown]
# ## Changing the column names

# %% [markdown]
# Also, if we have observed there is a same column name: total_runs with different functionality in deliveries.csv and most_runs_average_strikerate.csv. So we're changing the column names

# %%
# Rename the column 'old_column_name' to 'new_column_name'
df1 = df1.rename(columns={'total_runs': 'total_runs_currentdelivery'})
df3=df3.rename(columns={'total_runs': 'total_runs_overallmatches'})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   match_id                    179078 non-null  int64
#  1   inning                      179078 non-null  int64
#  2   batting_team                179078 non-null  object
#  3   bowling_team                179078 non-null  object
#  4   over                        179078 non-null  int64
#  5   ball                        179078 non-null  int64
#  6   batsman                     179078 non-null  object
#  7   non_striker                 179078 non-null  object
#  8   bowler                      179078 non-null  object
#  9   is_super_over               179078 non-null  int64
#  10  wide_runs                   179078 non-null  int64
#  11  bye_runs                    179078 non-null  int64
#  12  legbye_runs                 179078 non-null  int64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   batsman                    516 non-null    object
#  1   total_runs_overallmatches  516 non-null    int64
#  2   out                        516 non-null    int64
#  3   numberofballs              516 non-null    int64
#  4   average                    516 non-null    object
#  5   strikerate                 516 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 24.3+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             756 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           756 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  756 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          756 non-null    object
#  16  umpire2          756 non-null    object
# ...

# %% [markdown]
# ## Handling the Duplicates

# %% [markdown]
# As if we observe there's a Pune team with two different names which we're replaceing it with the correct team name

# %%
# Replacing "Rising Pune Supergiants" with "Rising Pune Supergiant" in df2
df2['winner'] = df2['winner'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df2['team1'] = df2['team1'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df2['team2'] = df2['team2'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df2['toss_winner'] = df2['toss_winner'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')

# %%
df2['team1'].value_counts()
# Out:
# team1
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Rising Pune Supergiant          15
# Gujarat Lions                   14
# Kochi Tuskers Kerala             7
# Delhi Capitals                   6
# Name: count, dtype: int64

# %%
df2['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiant         13
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Name: count, dtype: int64

# %%
df2['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# No Game Day                      4
# Name: count, dtype: int64

# %%
df2['team2'].value_counts()
# Out:
# team2
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant         15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            7
# Name: count, dtype: int64

# %%
# Replacing "Rising Pune Supergiants" with "Rising Pune Supergiant" in df1
df1['batting_team'] = df1['batting_team'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df1['bowling_team'] = df1['bowling_team'].replace('Rising Pune Supergiants', 'Rising Pune Supergiant')

# %%
df1['batting_team'].value_counts()
# Out:
# batting_team
# Mumbai Indians                 22619
# Kings XI Punjab                20931
# Royal Challengers Bangalore    20908
# Kolkata Knight Riders          20858
# Chennai Super Kings            19762
# Delhi Daredevils               18786
# Rajasthan Royals               17292
# Sunrisers Hyderabad            12908
# Deccan Chargers                 9034
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Rising Pune Supergiant          3480
# Delhi Capitals                  1909
# Kochi Tuskers Kerala            1582
# Name: count, dtype: int64

# %%
df1['bowling_team'].value_counts()
# Out:
# bowling_team
# Mumbai Indians                 22517
# Royal Challengers Bangalore    21236
# Kolkata Knight Riders          20940
# Kings XI Punjab                20782
# Chennai Super Kings            19556
# Delhi Daredevils               18725
# Rajasthan Royals               17382
# Sunrisers Hyderabad            12779
# Deccan Chargers                 9039
# Pune Warriors                   5457
# Gujarat Lions                   3545
# Rising Pune Supergiant          3543
# Delhi Capitals                  1963
# Kochi Tuskers Kerala            1614
# Name: count, dtype: int64

# %% [markdown]
# # DATA ANALYSIS USING DESCRIPTIVE STATISTICS

# %% [markdown]
# # Summary Statistics

# %% [markdown]
# Summary statistics provide a concise overview of key characteristics within a dataset, including measures such as mean, median, minimum, maximum, and standard deviation, offering insights into central tendencies, variability, and distribution of the data.

# %%
df1.drop(columns=['match_id']).describe()
# Out:
#               inning           over           ball  is_super_over  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        1.482952      10.162488       3.615587       0.000452
# std         0.502074       5.677684       1.806966       0.021263
# min         1.000000       1.000000       1.000000       0.000000
# 25%         1.000000       5.000000       2.000000       0.000000
# 50%         1.000000      10.000000       4.000000       0.000000
# 75%         2.000000      15.000000       5.000000       0.000000
# max         5.000000      20.000000       9.000000       1.000000
#
#            wide_runs       bye_runs    legbye_runs    noball_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.036721       0.004936       0.021136       0.004183
# std         0.251161       0.116480       0.194908       0.070492
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# count: This indicates the total number of observations or data points available for each variable. For instance, there are 179,078 observations for each variable in the dataset.
#
# mean: The mean represents the average value of each variable across all observations. For example, the mean value for the 'inning' variable is approximately 1.48, suggesting that, on average, the matches in the dataset have an inning value close to 1.48.
#
# std: The standard deviation measures the dispersion or spread of values around the mean. It indicates the degree of variability or deviation from the mean. For instance, a high standard deviation for the 'wide_runs' variable (0.25) suggests that there is considerable variability in the number of wide runs across observations.
#
# min: This denotes the minimum value observed for each variable in the dataset. For instance, the minimum value for the 'inning' variable is 1, indicating that the lowest inning number observed in the dataset is 1.
#
# 25%, 50%, 75%: These values represent the first quartile (Q1), median (Q2), and third quartile (Q3), respectively. They divide the data into four equal parts. For example, the 25th percentile value for the 'over' variable is 5, indicating that 25% of the observations have an over value of 5 or lower.
#
# max: This denotes the maximum value observed for each variable in the dataset. For instance, the maximum value for the 'total_runs_currentdelivery' variable is 10, indicating that the highest total runs scored in a single delivery is 10.

# %%
df2.drop(columns=['id']).describe()
# Out:
#        dl_applied  win_by_runs  win_by_wickets
# count  756.000000   756.000000      756.000000
# mean     0.025132    13.283069        3.350529
# std      0.156630    23.471144        3.387963
# min      0.000000     0.000000        0.000000
# 25%      0.000000     0.000000        0.000000
# 50%      0.000000     0.000000        4.000000
# 75%      0.000000    19.000000        6.000000
# max      1.000000   146.000000       10.000000

# %% [markdown]
# dl_applied:
#
# Count: There are 756 entries in this dataset.
# Mean: The mean value for 'dl_applied' is approximately 0.03, indicating that on average, the Duckworth-Lewis method was applied in around 3% of matches.
# Standard Deviation: The standard deviation is approximately 0.16, suggesting a relatively low variation around the mean.
# Min: The minimum value is 0, indicating that the Duckworth-Lewis method was not applied in some matches.
# 25th Percentile (Q1): 25% of the matches had 'dl_applied' equal to 0.
# Median (50th Percentile or Q2): 50% of the matches had 'dl_applied' equal to 0, indicating that the majority of matches did not have the Duckworth-Lewis method applied.
# 75th Percentile (Q3): 75% of the matches had 'dl_applied' equal to 0.
# Max: The maximum value is 1, suggesting that the Duckworth-Lewis method was applied in some matches.
#
# win_by_runs:
#
# Count: There are 756 entries in this dataset.
# Mean: The mean value for 'win_by_runs' is approximately 13.28, indicating that, on average, teams won by around 13 runs.
# Standard Deviation: The standard deviation is approximately 23.47, suggesting a considerable variation around the mean.
# Min: The minimum value is 0, indicating that some matches were won with no runs.
# 25th Percentile (Q1): 25% of the matches had 'win_by_runs' equal to 0, meaning that a quarter of the matches resulted in no runs.
# Median (50th Percentile or Q2): 50% of the matches had 'win_by_runs' equal to 0, indicating that half of the matches resulted in no runs.
# 75th Percentile (Q3): 75% of the matches had 'win_by_runs' less than or equal to 19.
# Max: The maximum value is 146, indicating a significant margin of victory in some matches.
#
# win_by_wickets:
#
# Count: There are 756 entries in this dataset.
# Mean: The mean value for 'win_by_wickets' is approximately 3.35, indicating that, on average, teams won with around 3 wickets remaining.
# Standard Deviation: The standard deviation is approximately 3.39, suggesting a moderate variation around the mean.
# Min: The minimum value is 0, indicating that some matches were won with no wickets remaining.
# 25th Percentile (Q1): 25% of the matches had 'win_by_wickets' equal to 0, meaning that a quarter of the matches resulted in no wickets remaining.
# Median (50th Percentile or Q2): 50% of the matches had 'win_by_wickets' equal to 4, indicating that half of the matches resulted in around 4 wickets remaining.
# 75th Percentile (Q3): 75% of the matches had 'win_by_wickets' less than or equal to 6.
# Max: The maximum value is 10, indicating that some matches were won with 10 wickets remaining.

# %%
df3.describe()
# Out:
#        total_runs_overallmatches         out  numberofballs  strikerate
# count                 516.000000  516.000000     516.000000  516.000000
# mean                  430.625969   17.063953     335.645349  105.433442
# std                   882.275431   28.124511     663.593679   39.633938
# min                     0.000000    0.000000       1.000000    0.000000
# 25%                    15.000000    2.000000      17.000000   84.362069
# 50%                    74.000000    5.500000      68.000000  111.651584
# 75%                   340.500000   18.000000     290.000000  130.499036
# max                  5426.000000  161.000000    4111.000000  250.000000

# %% [markdown]
# Count:
# There are 516 observations in the dataset for each variable, indicating the total number of data points available.
#
# Mean:
# The mean represents the average value of each variable across all observations. For example, the average total runs scored overall matches is approximately 430.63, the average number of times out is about 17.06, the average number of balls faced is around 335.65, and the average strikerate is roughly 105.43.
#
# Standard Deviation (Std):
# Standard deviation measures the dispersion or spread of the data points around the mean. A higher standard deviation indicates greater variability in the data.
# For instance, the standard deviation of total runs overall matches is 882.28, suggesting a wide range of scores across different matches.
#
# Minimum (Min) and Maximum (Max):
# These values represent the smallest and largest observations in the dataset, respectively.
# For example, the minimum total runs scored overall matches is 0, while the maximum is 5426.
#
# 25th, 50th (Median), and 75th Percentiles:
# These percentiles divide the data into four equal parts, with 25% of the data falling below the 25th percentile, 50% below the median (50th percentile), and 75% below the 75th percentile. They provide insights into the distribution of the data.
# For instance, the median number of balls faced is 68, indicating that half of the observations faced fewer balls than this value.

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# Correlation analysis examines the relationship between pairs of variables in a dataset, determining the extent to which changes in one variable correspond to changes in another, measured by the correlation coefficient, which ranges from -1 to 1.

# %%
# Drop the 'match_id' column from df1
df1_without_id = df1.drop(columns=['match_id'])

# Select only numeric columns for correlation
numeric_columns_df1 = df1_without_id.select_dtypes(include=['int64', 'float64']).columns

# Calculate correlation matrix
corr_matrix_df1 = df1_without_id[numeric_columns_df1].corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_df1, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for df1 (Excluding 'match_id')")
plt.show()

# %%
# Drop the 'id' column from df2
df2_without_id = df2.drop(columns=['id'])

# Select only numeric columns for correlation
numeric_columns_df2 = df2_without_id.select_dtypes(include=['int64', 'float64']).columns

# Calculate correlation matrix
corr_matrix_df2 = df2_without_id[numeric_columns_df2].corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_df2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for df2 (Excluding 'id')")
plt.show()

# %%
# Select only numeric columns for correlation
numeric_columns_df3 = df3.select_dtypes(include=['int64', 'float64']).columns

# Calculate correlation matrix
corr_matrix_df3 = df3[numeric_columns_df3].corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_df3, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix for df3")
plt.show()

# %% [markdown]
# # DATA AGGREGATION

# %% [markdown]
# Data aggregation involves the process of gathering and summarizing data from multiple sources or across various dimensions to provide meaningful insights or simplify complex datasets.

# %% [markdown]
# Here, we're combining the df1,df2,df3 to one dataset df

# %%
df = pd.merge(df1, df2, left_on='match_id', right_on='id', how='left')

# %%
df = pd.merge(df, df3, on='batsman', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   match_id                    179078 non-null  int64
#  1   inning                      179078 non-null  int64
#  2   batting_team                179078 non-null  object
#  3   bowling_team                179078 non-null  object
#  4   over                        179078 non-null  int64
#  5   ball                        179078 non-null  int64
#  6   batsman                     179078 non-null  object
#  7   non_striker                 179078 non-null  object
#  8   bowler                      179078 non-null  object
#  9   is_super_over               179078 non-null  int64
#  10  wide_runs                   179078 non-null  int64
#  11  bye_runs                    179078 non-null  int64
#  12  legbye_runs                 179078 non-null  int64
# ...

# %%
#data aggregation that calculates the total runs scored by each batting team:
# Grouping the data by 'batting_team' and calculating the total runs scored
batting_team_total_runs = df.groupby('batting_team')['total_runs_currentdelivery'].sum()

# Displaying the aggregated data
print("Total Runs Scored by Each Batting Team:")
print(batting_team_total_runs)
# Out:
# Total Runs Scored by Each Batting Team:
# batting_team
# Chennai Super Kings            26418
# Deccan Chargers                11463
# Delhi Capitals                  2630
# Delhi Daredevils               24388
# Gujarat Lions                   4862
# Kings XI Punjab                27893
# Kochi Tuskers Kerala            1901
# Kolkata Knight Riders          27419
# Mumbai Indians                 29809
# Pune Warriors                   6358
# Rajasthan Royals               22431
# Rising Pune Supergiant          4533
# Royal Challengers Bangalore    28126
# Sunrisers Hyderabad            17059
# Name: total_runs_currentdelivery, dtype: int64

# %%
#data aggregation that calculates the average strike rate of each batsman:
# Grouping the data by 'batsman' and calculating the average strike rate
batsman_average_strike_rate = df.groupby('batsman')['strikerate'].mean()

# Displaying the aggregated data
print("Average Strike Rate of Each Batsman:")
print(batsman_average_strike_rate)
# Out:
# Average Strike Rate of Each Batsman:
# batsman
# A Ashish Reddy    146.596859
# A Chandila         57.142857
# A Chopra           74.647887
# A Choudhary       125.000000
# A Dananjaya        80.000000
#                      ...
# YV Takawale       107.865169
# Yashpal Singh      71.212121
# Younis Khan        42.857143
# Yuvraj Singh      129.891561
# Z Khan             84.782609
# Name: strikerate, Length: 516, dtype: float64

# %% [markdown]
# # DATA VISUALIZATIONS

# %% [markdown]
# Using Data Visualization I want to answer the following questions:

# %% [markdown]
# 1. Which team has won the most matches in the dataset?
# 2. How does the average run rate vary across different seasons?
# 3. What is the trend of total runs scored by each team over different seasons?
# 4. How does the frequency of matches played vary across different venues?

# %% [markdown]
# # **Bar chart**
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.

# %% [markdown]
# # When to use it ?
# Compare categorical data.
# Comparisons among discrete categories.
# One axis of the chart shows the specific categories being compared, and the other axis represents a measured value.

# %% [markdown]
# # Question 1: Which team has won the most matches in the dataset?

# %%
# Define custom colors for each team
custom_colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta']

win_counts = df['winner'].value_counts().head(10)
win_counts.plot(kind='bar', figsize=(12, 6), color=custom_colors) 
plt.title('Top 10 Winning Teams')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels further and align them to the right
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# # Marks and Channels Used:

# %% [markdown]
# Marks:
# Vertical bars represent the number of wins for each team.
#
# Channels:
# Position (X-axis): Represents the teams.
# Position (Y-axis): Represents the number of wins.
# Length (Bars): Indicates the magnitude of wins for each team.
# Color (Bars): Could differentiate between different teams, although in this specific plot, all bars are the same color.

# %% [markdown]
# # Observations

# %% [markdown]
# The bar plot illustrates the number of wins for the top 10 winning teams in the dataset. Each bar represents a team, and its length corresponds to the number of wins accumulated by that team. From the visualization, it is evident that Mumbai Indians hold the highest number of wins, followed by Chennai Super Kings and Kolkata Knight Riders. The plot provides a clear comparison of the success rates among the top-performing teams, offering insights into their dominance in the league. Overall, it showcases the competitive landscape of the teams in the dataset, with Mumbai Indians emerging as the most successful team based on the number of wins.

# %% [markdown]
# # Line chart
# A line chart or line graph is a type of chart which displays information as a series of data points called 'markers' connected by straight line segments. A line chart is often used to visualize a trend in data over intervals of time – a time series – thus the line is often drawn chronologically.

# %% [markdown]
# # When to use it ?
# Track changes over time
# x-axis displays continuous variables
# Y-axis displays measurement

# %% [markdown]
# # Question 2: How does the average run rate vary across different seasons?

# %%
df['run_rate'] = df['total_runs_currentdelivery'] / df['numberofballs']  # Calculate run rate
season_avg_run_rate = df.groupby('Season')['run_rate'].mean()
season_avg_run_rate.plot(kind='line', figsize=(10, 6), marker='o', color='green')
plt.title('Average Run Rate Across Seasons')
plt.xlabel('Season')
plt.ylabel('Average Run Rate')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # Marks and Channels Used:

# %% [markdown]
# Marks:
# points along the line where data is plotted, The markers specified by marker='o' indicate each data point along the line.
#
# Channels:
# Position (X-axis): Represents the seasons.
# Position (Y-axis): Represents the average run rate for each season.
# Color (Line): The color of the line represents the data series (average run rate).

# %% [markdown]
# # Observations:

# %% [markdown]
# The line plot depicts the average run rate across different seasons of the IPL (Indian Premier League). It illustrates the trend of run rates over time, providing insights into the scoring patterns in each season. From the graph, it's evident that there are fluctuations in the average run rate from season to season, with some seasons witnessing higher run rates compared to others. The highest average run rate appears to be in the IPL-2019 season, while the lowest is observed in IPL-2015. This analysis helps in understanding the pace of scoring in each IPL season and can be valuable for assessing the overall competitiveness and excitement of matches over the years.

# %% [markdown]
# # Stacked area chart
# Stacked Area Graphs work in the same way as simple Area Graphs do, except for the use of multiple data series that start each point from the point left by the previous data series.

# %% [markdown]
# # When to use it ?
# Represent cumulated totals using numbers or percentages over time.
# Visualize part-to-whole relationships, helping show how each category contributes to the cumulative total.

# %% [markdown]
# # Question 3: What is the trend of total runs scored by each team over different seasons?

# %%
team_season_runs = df.groupby(['Season', 'batting_team'])['total_runs_currentdelivery'].sum().unstack(fill_value=0)
team_season_runs.plot(kind='area', stacked=True, figsize=(12, 6))
plt.title('Total Runs Scored by Each Team Over Seasons')
plt.xlabel('Season')
plt.ylabel('Total Runs')
plt.xticks(rotation=45)
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Marks and Channels Used:

# %% [markdown]
# Marks:
# Filled areas represent the total runs scored by each team.
#
# Channels:
# Position (X-axis): Represents the seasons.
# Position (Y-axis): Represents the total runs scored.
# Color (Areas): Differentiates between teams. Each team's area is filled with a different color.

# %% [markdown]
# # Observations:

# %% [markdown]
# The stacked area chart displays the total runs scored by each team over different seasons in the Indian Premier League (IPL). Each color represents a different team, and the height of each color segment at any given point on the x-axis represents the total runs scored by that team in a particular season.
#
# From the chart, we can observe the overall trend of runs scored by each team across seasons. For instance, teams like Mumbai Indians, Chennai Super Kings, and Royal Challengers Bangalore consistently appear to score higher totals across multiple seasons, indicating their strong batting performances. On the other hand, some teams like Kochi Tuskers Kerala and Pune Warriors show lower total runs, possibly due to their shorter presence in the IPL or lower overall performance.
#
# Additionally, fluctuations in the height of the colored segments within each season reveal variations in the performance of teams from one season to another. This visualization provides insights into the batting prowess of each team over time and can help in analyzing the historical performance and trends of IPL teams in terms of run-scoring abilities.

# %% [markdown]
# # Stacked bar chart
# Alternatively, a stacked bar chart could be used. The stacked bar chart stacks bars that represent different groups on top of each other. The height of the resulting bar shows the combined result of the groups.

# %% [markdown]
# # When to use it ?
# To compare the totals and one part of the totals.
# If the total of your parts is crucial, stacked column chart can work well for dates.

# %% [markdown]
# # Question 4: How does the frequency of matches played vary across different venues?

# %%
venue_counts = df['venue'].value_counts().head(10)  # Get the top 10 venues by match frequency

venue_df = df[df['venue'].isin(venue_counts.index)]
venue_counts_stacked = venue_df.groupby(['venue', 'winner']).size().unstack(fill_value=0)

venue_counts_stacked.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Match Outcomes by Venue (Top 10 Venues)')
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.xticks(range(len(venue_counts_stacked.index)), venue_counts_stacked.index)
plt.tight_layout()
plt.legend(title='Winner', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Marks and Channels Used:

# %% [markdown]
# Marks:
# Rectangular bars represent each category (venue).
# Different segments within each bar represent different categories (winners).
#
# Channels:
# Position (X-axis): Represents the venues where matches were played.
# Position (Y-axis): Represents the number of matches played.
# Color (Segments): Differentiates between winners. Each segment of the bar is colored according to the winning team.

# %% [markdown]
# # Observations:

# %% [markdown]
# The stacked bar chart representation above shows the frequency of matches played at the top 10 venues, along with the number of matches won by each team at those venues. Each row corresponds to a specific venue, and each column represents a team that has won matches at that venue. For example, at the Eden Gardens venue, Kolkata Knight Riders won the highest number of matches, followed by Chennai Super Kings,and others. Similarly, the bar chart provides insights into the match outcomes at other popular venues such as Feroz Shah Kotla, M Chinnaswamy Stadium, and Wankhede Stadium. This table offers a comprehensive view of the match frequency and team performances across different venues, aiding in the analysis of venue preferences and team strengths in various locations.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, the analysis of this dataset provides valuable insights into the dynamics of the Indian Premier League (IPL) matches over the years. Through visualizations and statistical summaries, we have examined various aspects such as team performances, match outcomes at different venues, run rates across seasons, and total runs scored by each team.
#
# From the analysis, we observe that Mumbai Indians emerge as the most successful team in terms of the number of wins, closely followed by Chennai Super Kings and Kolkata Knight Riders. The distribution of matches across different venues highlights the popularity of stadiums like Eden Gardens, Feroz Shah Kotla, and M Chinnaswamy Stadium.
#
# Furthermore, the trends in average run rates across seasons provide insights into the changing dynamics of the game over the years. We can observe fluctuations in run rates, indicating the evolving strategies and playing conditions in different seasons.
#
# Overall, this dataset analysis offers a comprehensive understanding of the IPL matches, enabling stakeholders to make informed decisions and strategies in the context of team performance, venue selection, and seasonal variations.
